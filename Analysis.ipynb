# %% [markdown]
# ## **Teste do Modelo**

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO
from glob import glob

path_images = glob(r'New Images\*.jpg')

for path_image in path_images:

    model = YOLO(r'AI Training\runs\detect\runs\exp1-2\weights\best.pt')
    results = model.predict(
        source=path_image,
        save=True,
        conf=0.25
    )


    fig, (left, right) = plt.subplots(1, 2, figsize=(12, 6))
        
    left.imshow(plt.imread(path_image))
    left.axis('off') # Esconde os eixos numéricos
    left.set_title("Imagem Original")


    plt.imshow(results[0].plot()[:, :, ::-1])
    right.axis('off') # Esconde os eixos numéricos
    right.set_title("Detecção de Heliponto")
    plt.show()
# Out:
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194543_y298181.jpg: 640x640 1 heliponto, 527.4ms
# Speed: 5.4ms preprocess, 527.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-13
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194545_y298183.jpg: 640x640 1 heliponto, 227.2ms
# Speed: 11.3ms preprocess, 227.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-14
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194545_y298184.jpg: 640x640 2 helipontos, 945.2ms
# Speed: 10.3ms preprocess, 945.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-15
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194546_y298177.jpg: 640x640 (no detections), 272.1ms
# Speed: 57.1ms preprocess, 272.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-16
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194546_y298178.jpg: 640x640 (no detections), 803.8ms
# Speed: 87.0ms preprocess, 803.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-17
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194546_y298179.jpg: 640x640 (no detections), 334.8ms
# Speed: 9.6ms preprocess, 334.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-18
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194546_y298180.jpg: 640x640 (no detections), 337.3ms
# Speed: 19.0ms preprocess, 337.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-19
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194547_y298176.jpg: 640x640 1 heliponto, 734.8ms
# Speed: 59.8ms preprocess, 734.8ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-20
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194548_y298180.jpg: 640x640 (no detections), 374.8ms
# Speed: 8.2ms preprocess, 374.8ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-21
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194548_y298181.jpg: 640x640 1 heliponto, 281.1ms
# Speed: 12.0ms preprocess, 281.1ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-22
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194548_y298183.jpg: 640x640 (no detections), 300.0ms
# Speed: 12.3ms preprocess, 300.0ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-23
# image 1/1 c:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\New Images\tile_z19_x194549_y298187.jpg: 640x640 1 heliponto, 212.2ms
# Speed: 8.3ms preprocess, 212.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\PP\OneDrive - Fundao So Paulo\PUC-SP\5 Semestre\Aprendizagem de Mquina\Projeto 02\Helipoint-Detector\runs\detect\predict-24

# %% [markdown]
# # **Análise do Modelo**

# %%
import seaborn as sns
import pandas as pd

results_df = pd.read_csv(r'AI Training\runs\detect\runs\exp1-2\results.csv')
results_df
# Out:
#     epoch       time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1    6.39574         1.33875         3.44081         1.55389
# 1       2   10.26110         1.26203         2.87580         1.41426
# 2       3   14.44790         1.21268         2.49484         1.36679
# 3       4   17.85260         1.29544         2.51040         1.44549
# 4       5   21.17220         1.24292         2.37024         1.35180
# 5       6   25.53310         1.13395         2.12609         1.28154
# 6       7   28.82460         1.16481         2.02161         1.36591
# 7       8   32.09310         1.26049         2.05527         1.45221
# 8       9   35.68850         1.25084         2.94947         1.38563
# 9      10   39.77500         1.37080         2.32565         1.49888
# 10     11   43.40380         1.20506         1.83758         1.41040
# 11     12   46.46420         1.16279         1.88029         1.33662
# 12     13   50.40330         1.11974         1.78849         1.36058
# 13     14   55.30660         1.29714         1.78397         1.51350
# 14     15   58.58260         1.19200         1.72338         1.38605
# 15     16   61.73290         1.14932         1.57519         1.34292
# 16     17   67.36040         1.00709         1.39658         1.25578
# 17     18   70.86000         1.03531         1.50460         1.30575
# 28              0.85253       0.81633       0.99782       1.17186  0.001076
# 29              0.75197       0.82046       1.57136       1.16063  0.001043
# 30              0.80897       0.75486       1.27582       1.11717  0.001010
# 31              0.82360       0.82734       1.24989       1.16197  0.000977
# 32              0.82380       1.04349       1.05290       1.44471  0.000944
# 33              0.79716       0.97659       1.26660       1.39010  0.000911
# 34              0.79299       0.97155       1.66115       1.34610  0.000878
# 35              0.82215       0.85408       1.20462       1.19628  0.000845
# 36              0.77898       0.82304       1.22430       1.18503  0.000812
# 37              0.81009       0.77879       0.86815       1.16276  0.000779
# 38              0.79005       0.88070       0.96095       1.22788  0.000746
# 39              0.71547       1.13532       1.30045       1.66280  0.000713
# 40              0.77662       1.01429       0.89328       1.48826  0.000680
# 41              0.84038       0.92163       0.86879       1.28010  0.000647
# 42              0.81171       1.16175       1.64027       1.48442  0.000614
# 43              0.82919       1.26869       1.38032       1.60608  0.000581
# 44              0.82222       0.94547       1.12949       1.25713  0.000548
# 45              0.83186       0.74067       0.98772       1.13420  0.000515
# 46              0.81408       0.69466       0.99192       1.14080  0.000482
# 47              0.81438       0.71258       0.80399       1.15559  0.000449
# 48              0.83936       0.64153       0.68498       1.12704  0.000416
# 49              0.85148       0.65478       0.73577       1.11609  0.000383
# 50              0.86214       0.67578       1.02150       1.11131  0.000350
# 51              0.84210       0.70569       1.37945       1.11973  0.000317
# 52              0.85547       0.66331       1.04750       1.08410  0.000284
# 53              0.88115       0.63300       0.73008       1.06981  0.000251
# 54              0.87002       0.63340       0.69168       1.06878  0.000218
# 55              0.85238       0.62920       0.74035       1.08201  0.000185
# 56              0.84882       0.64320       0.79402       1.09833  0.000152
# 57              0.83906       0.64447       0.80027       1.10837  0.000119
# 58              0.84000       0.63701       0.78229       1.10534  0.000086
# 59              0.84093       0.62707       0.77347       1.09392  0.000053
#
#       lr/pg1    lr/pg2
# 0   0.000220  0.000220
# 1   0.000452  0.000452
# 2   0.000677  0.000677
# 3   0.000893  0.000893
# 4   0.001102  0.001102
# 5   0.001303  0.001303
# 6   0.001496  0.001496
# 7   0.001681  0.001681
# 8   0.001736  0.001736
# 9   0.001703  0.001703
# 10  0.001670  0.001670
# 11  0.001637  0.001637
# 12  0.001604  0.001604
# 13  0.001571  0.001571
# 14  0.001538  0.001538
# 15  0.001505  0.001505
# 16  0.001472  0.001472
# 17  0.001439  0.001439
# 18  0.001406  0.001406
# 19  0.001373  0.001373
# 20  0.001340  0.001340
# 21  0.001307  0.001307
# 22  0.001274  0.001274
# 23  0.001241  0.001241
# 24  0.001208  0.001208
# 25  0.001175  0.001175
# 26  0.001142  0.001142
# 27  0.001109  0.001109
# 28  0.001076  0.001076
# 29  0.001043  0.001043
# 30  0.001010  0.001010
# 31  0.000977  0.000977
# 32  0.000944  0.000944
# 33  0.000911  0.000911
# 34  0.000878  0.000878
# 35  0.000845  0.000845
# 36  0.000812  0.000812
# 37  0.000779  0.000779
# 38  0.000746  0.000746
# 39  0.000713  0.000713
# 40  0.000680  0.000680
# 41  0.000647  0.000647
# 42  0.000614  0.000614
# 43  0.000581  0.000581
# 44  0.000548  0.000548
# 45  0.000515  0.000515
# 46  0.000482  0.000482
# 47  0.000449  0.000449
# 48  0.000416  0.000416
# 49  0.000383  0.000383
# 50  0.000350  0.000350
# 51  0.000317  0.000317
# 52  0.000284  0.000284
# 53  0.000251  0.000251
# 54  0.000218  0.000218
# 55  0.000185  0.000185
# 56  0.000152  0.000152
# 57  0.000119  0.000119
# 58  0.000086  0.000086
# 59  0.000053  0.000053

# %%
fig, (up, middle, down) = plt.subplots(3, 1, figsize=(12, 15))

sns.lineplot(data=results_df, x='epoch', y='train/box_loss', marker='o', linestyle='-', label='train/box_loss', ax=up)
sns.lineplot(data=results_df, x='epoch', y='val/box_loss', marker='o', linestyle='-', label='val/box_loss', ax=up)
up.set_title("Box Loss")
up.set_ylabel("box_loss")
up.spines['top'].set_visible(False)
up.spines['right'].set_visible(False)
up.spines['left'].set_visible(False)
up.grid(axis='y', linestyle='--', alpha=0.7)


sns.lineplot(data=results_df, x='epoch', y='train/cls_loss', marker='o', linestyle='-', label='train/cls_loss', ax=middle)
sns.lineplot(data=results_df, x='epoch', y='val/cls_loss', marker='o', linestyle='-', label='val/cls_loss', ax=middle)
middle.set_title("Loss de Classificação")
middle.set_ylabel("cls_loss")
middle.spines['top'].set_visible(False)
middle.spines['right'].set_visible(False)
middle.spines['left'].set_visible(False)
middle.grid(axis='y', linestyle='--', alpha=0.7)


sns.lineplot(data=results_df, x='epoch', y='train/dfl_loss', marker='o', linestyle='-', label='train/dfl_loss', ax=down)
sns.lineplot(data=results_df, x='epoch', y='val/dfl_loss', marker='o', linestyle='-', label='val/dfl_loss', ax=down)
down.set_title("Loss de Distribuição")
down.set_ylabel("dfl_loss")
down.spines['top'].set_visible(False)
down.spines['right'].set_visible(False)
down.spines['left'].set_visible(False)
down.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
fig, (up, down) = plt.subplots(2, 1, figsize=(12, 10))

sns.lineplot(data=results_df, x='epoch', y='metrics/precision(B)', marker='o', linestyle='-', label='metrics/precision(B)', ax=up)
up.set_title("Precision(B)")
up.set_ylabel("precision(B)")
up.spines['top'].set_visible(False)
up.spines['right'].set_visible(False)
up.spines['left'].set_visible(False)
up.grid(axis='y', linestyle='--', alpha=0.7)


sns.lineplot(data=results_df, x='epoch', y='metrics/recall(B)', marker='o', linestyle='-', label='metrics/recall(B)', ax=down)
down.set_title("Recall(B)")
down.set_ylabel("recall(B)")
down.spines['top'].set_visible(False)
down.spines['right'].set_visible(False)
down.spines['left'].set_visible(False)
down.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=results_df, x='epoch', y='metrics/mAP50(B)', marker='o', linestyle='-', label='mAP50(B)')
sns.lineplot(data=results_df, x='epoch', y='metrics/mAP50-95(B)', marker='o', linestyle='-', label='mAP50-95(B)')
plt.title('mAP50(B) e mAP50-95(B) por Época')
plt.xlabel('Época')
plt.ylabel('mAP50(B) e mAP50-95(B)')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.grid(axis = 'y', alpha=0.3)
plt.tight_layout()
