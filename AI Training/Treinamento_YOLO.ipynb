# %%
# !pip install -q ultralytics roboflow torch

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="3wgHWERwqAGR7r8E7sSy")
project = rf.workspace("pedros-workspace-1w4rz").project("my-first-project-kfo4l")

version = project.version(2)

dataset = version.download("yolov8")

print(project.versions())
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# [<roboflow.core.version.Version object at 0x7b1f01540e90>, <roboflow.core.version.Version object at 0x7b1f01540e00>]

# %%
import torch

def selecionar_device():
    if torch.backends.mps.is_available():
        return torch.device("mps")
    if torch.cuda.is_available():
        return torch.device("cuda")
    return torch.device("cpu")

device = selecionar_device()
device
# Out:
# device(type='cuda')

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data=r'My-First-Project-2/data.yaml',
    epochs=60,          
    imgsz=640,
    batch=16,           
    device=device, 
    seed=42,           
    project='runs', name='exp1'
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.74 available 😃 Update with 'pip install -U ultralytics'
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import shutil
from google.colab import files

# Define the folder to be zipped (assuming 'My-First-Project-1')
folder_to_zip = 'My-First-Project-2'
output_filename = 'My-First-Project-2_zipped'

# Create a zip archive of the folder
shutil.make_archive(output_filename, 'zip', folder_to_zip)
shutil.make_archive('runs_zipped', 'zip', 'runs')

print(f'Folder "{folder_to_zip}" successfully zipped to "{output_filename}.zip"')

# %%
# Download the zipped file
files.download(f'{output_filename}.zip')
